# %%
import pandas as pd
import numpy as np 
df = pd.read_csv('Nike_Sales_Uncleaned.csv')
df = pd.read_csv('Nike_Sales_Uncleaned.csv')
df.head()
# Out:
#    Order_ID Gender_Category Product_Line    Product_Name Size  Units_Sold  \
# 0      2000            Kids     Training     SuperRep Go    M         NaN
# 1      2001           Women       Soccer   Tiempo Legend    M         3.0
# 2      2002           Women       Soccer     Premier III    M         4.0
# 3      2003            Kids    Lifestyle      Blazer Mid    L         NaN
# 4      2004            Kids      Running  React Infinity   XL         NaN
#
#        MRP  Discount_Applied  Revenue  Order_Date Sales_Channel     Region  \
# 0      NaN              0.47      0.0  2024-03-09        Online  bengaluru
# 1  4957.93               NaN      0.0  2024-07-09        Retail        Hyd
# 2      NaN               NaN      0.0         NaN        Retail     Mumbai
# 3  9673.57               NaN      0.0  04-10-2024        Online       Pune
# 4      NaN               NaN      0.0  2024/09/12        Retail      Delhi
#
#     Profit
# 0  -770.45
# 1  -112.53
# 2  3337.34
# 3  3376.85
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

df.isnull().sum()
# Out:
# Order_ID               0
# Gender_Category        0
# Product_Line           0
# Product_Name           0
# Size                 510
# Units_Sold          1235
# MRP                 1254
# Discount_Applied    1668
# Revenue                0
# Order_Date           616
# Sales_Channel          0
# Region                 0
# Profit                 0
# dtype: int64

# %%
df.shape
# Out:
# (2500, 13)

# %%
df.dtypes
# Out:
# Order_ID              int64
# Gender_Category      object
# Product_Line         object
# Product_Name         object
# Size                 object
# Units_Sold          float64
# MRP                 float64
# Discount_Applied    float64
# Revenue             float64
# Order_Date           object
# Sales_Channel        object
# Region               object
# Profit              float64
# dtype: object

# %%
df['Size'].fillna(df['Size'].mode()[0], inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_19872\2279563953.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Size'].fillna(df['Size'].mode()[0], inplace=True)

# %%
df.Size.isnull().sum()
# Out:
# np.int64(0)

# %%
#mode to obj value of null
df['Order_Date'].fillna(df['Order_Date'].mode()[0], inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_19872\2051167563.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Order_Date'].fillna(df['Order_Date'].mode()[0], inplace=True)

# %%
df.Order_Date.isnull().sum()
# Out:
# np.int64(0)

# %%
#mean to fload value of null
df['MRP'].fillna(df['MRP'].mean(), inplace=True)
df['Discount_Applied'].fillna(0, inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_19872\1486876729.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['MRP'].fillna(df['MRP'].mean(), inplace=True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_19872\1486876729.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df['Units_Sold'].fillna(df['Units_Sold'].mean(), inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_19872\3176916641.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Units_Sold'].fillna(df['Units_Sold'].mean(), inplace=True)

# %%
df['Discount_Applied'].unique()
# Out:
# array([0.47, 0.  , 0.32, 0.86, 0.3 , 1.17, 0.67, 0.66, 0.5 , 0.16, 0.22,
#        1.05, 0.82, 1.07, 0.38, 1.01, 0.83, 0.63, 0.77, 1.04, 0.57, 0.37,
#        0.94, 0.78, 0.49, 0.85, 0.21, 0.45, 0.6 , 1.13, 0.29, 0.69, 0.27,
#        0.42, 1.14, 0.53, 0.41, 1.24, 0.24, 0.74, 0.95, 1.1 , 1.12, 0.48,
#        0.09, 0.8 , 0.01, 1.06, 1.2 , 1.16, 0.59, 0.9 , 0.51, 0.65, 0.97,
#        0.36, 0.11, 0.12, 0.31, 0.89, 0.84, 0.39, 0.54, 1.08, 1.03, 0.07,
#        1.22, 0.26, 0.25, 0.81, 0.08, 0.71, 0.56, 0.06, 0.91, 0.93, 1.23,
#        0.34, 0.05, 0.35, 0.88, 1.02, 1.25, 1.19, 0.2 , 0.03, 1.11, 0.14,
#        0.15, 1.15, 0.1 , 0.79, 0.04, 0.19, 0.62, 1.09, 0.33, 0.18, 0.75,
#        0.99, 0.55, 0.72, 0.76, 0.7 , 0.44, 1.18, 0.43, 1.21, 0.73, 1.  ,
#        0.02, 0.68, 0.96, 0.23, 0.98, 0.61, 0.28, 0.58, 0.46, 0.17, 0.87,
#        0.13, 0.52, 0.4 , 0.92, 0.64])

# %%
df.isnull().sum()
# Out:
# Order_ID            0
# Gender_Category     0
# Product_Line        0
# Product_Name        0
# Size                0
# Units_Sold          0
# MRP                 0
# Discount_Applied    0
# Revenue             0
# Order_Date          0
# Sales_Channel       0
# Region              0
# Profit              0
# dtype: int64

# %%
negative_sales = df[df['Units_Sold'] < 0]
print(negative_sales)
# Out:
#       Order_ID Gender_Category Product_Line        Product_Name Size  \
# 8         2008           Women       Soccer         Premier III   11
# 11        2011           Women     Training        Flex Trainer    L
# 12        2018            Kids    Lifestyle          Blazer Mid    L
# 20        2020            Kids       Soccer       Tiempo Legend    L
# 21        2021             Men      Running             Free RN    L
# 33        2033             Men       Soccer  Mercurial Superfly   XL
# 54        2054           Women     Training        Flex Trainer   11
# 59        2059            Kids       Soccer          Phantom GT    L
# 66        2066             Men       Soccer          Phantom GT   XL
# 74        2074             Men     Training        Flex Trainer    L
# 79        2079             Men      Running       Pegasus Turbo   XL
# 82        2028             Men      Running             Free RN    L
# 102       2102           Women       Soccer  Mercurial Superfly   XL
# ...

# %%
df.loc[df['Units_Sold'] < 0, 'Units_Sold'] = np.nan

# %%
min_value = df["Units_Sold"].min()
print(min_value)
# Out:
# 0.0

# %%
df.isnull().sum()
# Out:
# Order_ID              0
# Gender_Category       0
# Product_Line          0
# Product_Name          0
# Size                  0
# Units_Sold          205
# MRP                   0
# Discount_Applied      0
# Revenue               0
# Order_Date            0
# Sales_Channel         0
# Region                0
# Profit                0
# dtype: int64

# %%
df["Units_Sold"].fillna(df["Units_Sold"].median(),inplace=True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_19872\3227812724.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Units_Sold"].fillna(df["Units_Sold"].median(),inplace=True)

# %%
df.to_csv("C:/Users/User/BPS_Batch-30/cleaned_nikesale.csv")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df.to_csv("C:/Users/User/BPS_Batch-30/cleaned_nikesale.csv")
#
# File d:\BPS_Batch-30\Nike\.venv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
